# %%
import pandas as pd
# Out:
# C:\Users\inder\AppData\Local\Temp\ipykernel_7196\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
met=pd.read_csv('metClean.csv')
key=pd.read_csv('keyClean.csv')
# Out:
# C:\Users\inder\AppData\Local\Temp\ipykernel_7196\2281707588.py:1: DtypeWarning: Columns (1,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   met=pd.read_csv('metClean.csv')

# %%
met
# Out:
#        belongs_to_collection    budget     genres      id original_language  \
# 0       Toy Story Collection  30000000  Animation     862                en
# 1       Toy Story Collection  30000000     Comedy     862                en
# 2       Toy Story Collection  30000000     Family     862                en
# 3                        NaN  65000000  Adventure    8844                en
# 4                        NaN  65000000  Adventure    8844                en
# ...                      ...       ...        ...     ...               ...
# 413320                   NaN         0     Action   67758                en
# 413321                   NaN         0      Drama   67758                en
# 413322                   NaN         0   Thriller   67758                en
# 413323                   NaN         0        NaN  227506                en
# 413324                   NaN         0        NaN  461257                en
#
# ...

# %%
met.dropna(subset=['title'],inplace=True)

# %%
met[met['id']==862]
# Out:
#   belongs_to_collection    budget     genres   id original_language  \
# 0  Toy Story Collection  30000000  Animation  862                en
# 1  Toy Story Collection  30000000     Comedy  862                en
# 2  Toy Story Collection  30000000     Family  862                en
#
#   popularity     production_companies      production_countries release_date  \
# 0  21.946943  Pixar Animation Studios  United States of America   1995-10-30
# 1  21.946943  Pixar Animation Studios  United States of America   1995-10-30
# 2  21.946943  Pixar Animation Studios  United States of America   1995-10-30
#
#        revenue  runtime spoken_languages    status      title  vote_average  \
# 0  373554033.0     81.0          English  Released  Toy Story           7.7
# 1  373554033.0     81.0          English  Released  Toy Story           7.7
# 2  373554033.0     81.0          English  Released  Toy Story           7.7
#
#    vote_count
# 0      5415.0
# 1      5415.0
# 2      5415.0

# %%
key[key['id']==862]
# Out:
#     id                                     keywords      keywords_name  \
# 0  862              {'id': 931, 'name': 'jealousy'}           jealousy
# 1  862                  {'id': 4290, 'name': 'toy'}                toy
# 2  862                  {'id': 5202, 'name': 'boy'}                boy
# 3  862           {'id': 6054, 'name': 'friendship'}         friendship
# 4  862              {'id': 9713, 'name': 'friends'}            friends
# 5  862              {'id': 9823, 'name': 'rivalry'}            rivalry
# 6  862      {'id': 165503, 'name': 'boy next door'}      boy next door
# 7  862            {'id': 170722, 'name': 'new toy'}            new toy
# 8  862  {'id': 187065, 'name': 'toy comes to life'}  toy comes to life
#
#    keywords_id
# 0          931
# 1         4290
# 2         5202
# 3         6054
# 4         9713
# 5         9823
# 6       165503
# 7       170722
# 8       187065

# %%
met['id']=met['id'].astype(int)

# %%
met['id'].unique()
# Out:
# array([   862,   8844,  15602, ...,  67758, 227506, 461257])

# %%
key['id'].unique()
# Out:
# array([   862,   8844,  15602, ..., 289923, 439050, 111109], dtype=int64)

# %%
merged=pd.merge(met,key,on='id',how='left')

# %%
toy=merged[merged['id']==862]

# %%
toy.drop(columns=['keywords','keywords_id'],inplace=True)
# Out:
# C:\Users\inder\AppData\Local\Temp\ipykernel_7196\1792326849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy.drop(columns=['keywords','keywords_id'],inplace=True)

# %%
toy.to_csv('test.csv',index=False)

# %%
toy.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'title', 'vote_average', 'vote_count', 'keywords_name'],
#       dtype='object')
